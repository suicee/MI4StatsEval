# %% [markdown]
# # Estimate MI with BA Bound

# %%
from tools.Trainer import train_ba,train_mine
import numpy as np
from tools.Trainer import feature_selection
from tools.Trainer import train_mine_with_r,train_mine

# %% [markdown]
# ## Pure Signal

# %% [markdown]
# ### 1. ST

# %%
st_pure=np.load('dataset/data_for_paper/pure_signal/ST.npy')
param=np.load('dataset/data_for_paper/pure_signal/params.npy')

# %%
st_pure=(st_pure-np.mean(st_pure,axis=0))/np.std(st_pure,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %% [markdown]
# To mitigate the risk of overfitting, we employ a dataset splitting strategy, dividing the dataset into a training set and a validation set. The training set is utilized for training the normalizing flow (NF) model, while the validation set is used for model validation. Subsequently, we select the model with the highest validation score to calculate the mutual information (MI) estimation across the entire dataset.

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    st_pure,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 5.135691877370501

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    st_pure,
    param,
    MI_estimator_name='smile',
    train_info={'epochs':2000,'batch_size':1000,'learning_rate':1e-3,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.5227605454753365

# %% [markdown]
# ### 2. PS

# %%
ps_pure=np.load('dataset/data_for_paper/pure_signal/PS.npy')
param=np.load('dataset/data_for_paper/pure_signal/params.npy')

# %%
ps_pure=(ps_pure-np.mean(ps_pure,axis=0))/np.std(ps_pure,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    ps_pure,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 4.030031915670062

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    ps_pure,
    param,
    MI_estimator_name='nwj',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.28606709508233896

# %% [markdown]
# ### 3. BS

# %%
bs_pure=np.load('dataset/data_for_paper/pure_signal/BS.npy')
param=np.load('dataset/data_for_paper/pure_signal/params.npy')

# %%
bs_pure=(bs_pure-np.mean(bs_pure,axis=0))/np.std(bs_pure,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    bs_pure,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 3.7543404064232355

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    bs_pure,
    param,
    MI_estimator_name='smile',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.24272749201730154

# %% [markdown]
# ### 4. BS&PS

# %%
bs=np.load('dataset/data_for_paper/pure_signal/BS.npy')
ps=np.load('dataset/data_for_paper/pure_signal/PS.npy')
pb_pure=np.hstack([ps,bs])
param=np.load('dataset/data_for_paper/pure_signal/params.npy')

# %%
pb_pure=(pb_pure-np.mean(pb_pure,axis=0))/np.std(pb_pure,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    pb_pure,
    param,
    train_info={'epochs':1000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 4.679064746862078

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    pb_pure,
    param,
    MI_estimator_name='smile',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.060355943497430564

# %% [markdown]
# ## Signal With Noise

# %% [markdown]
# ### 1. ST

# %%
st_ns=np.load('dataset/data_for_paper/signal_with_noise/ST.npy')
param=np.load('dataset/data_for_paper/signal_with_noise/params.npy')

# %%
st_ns=(st_ns-np.mean(st_ns,axis=0))/np.std(st_ns,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    st_ns,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 1.0433226785713676

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    st_ns,
    param,
    MI_estimator_name='nwj',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.026253831436644066

# %% [markdown]
# ### 2. PS

# %%
ps_ns=np.load('dataset/data_for_paper/signal_with_noise/PS.npy')
param=np.load('dataset/data_for_paper/signal_with_noise/params.npy')

# %%
ps_ns=(ps_ns-np.mean(ps_ns,axis=0))/np.std(ps_ns,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    ps_ns,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 0.6848843655640129

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    ps_ns,
    param,
    MI_estimator_name='nwj',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.14333860941900442

# %% [markdown]
# ### 3. BS

# %%
bs_ns=np.load('dataset/data_for_paper/signal_with_noise/BS.npy')
param=np.load('dataset/data_for_paper/signal_with_noise/params.npy')

# %%
bs_ns=(bs_ns-np.mean(bs_ns,axis=0))/np.std(bs_ns,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
# best_model,train_MIs,eval_MIs,total_MIs=train_ba(
#     bs_ns,
#     param,
#     train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
#     verbose=True)

# %% [markdown]
# Final Results

# %%
# total_MIs[-1]

# %% [markdown]
# To alleviate overfitting issues, we add a feature selection step

# %%
mask=feature_selection(bs_ns,param)
bs_ns=bs_ns[:,mask]

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    bs_ns,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.3343690595680717

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    bs_ns,
    param,
    MI_estimator_name='smile',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.038146501780748604

# %% [markdown]
# ### 4. BS&PS

# %%
bs_ns=np.load('dataset/data_for_paper/signal_with_noise/BS.npy')
ps_ns=np.load('dataset/data_for_paper/signal_with_noise/PS.npy')

pb_ns=np.hstack([ps_ns,bs_ns])
param=np.load('dataset/data_for_paper/signal_with_noise/params.npy')

# %%
pb_ns=(pb_ns-np.mean(pb_ns,axis=0))/np.std(pb_ns,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
mask=feature_selection(pb_ns,param)
pb_ns=pb_ns[:,mask]

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    pb_ns,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 1.0424740276390556

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    pb_ns,
    param,
    MI_estimator_name='nwj',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.13437788299046222

# %% [markdown]
# ## Signal with Noise and Foreground

# %% [markdown]
# ### 1. ST

# %%
st_obs=np.load('dataset/data_for_paper/signal_with_fg_ns/ST.npy')
param=np.load('dataset/data_for_paper/signal_with_fg_ns/params.npy')

# %%
st_obs=(st_obs-np.mean(st_obs,axis=0))/np.std(st_obs,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    st_obs,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 0.5130763611847404

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    st_obs,
    param,
    MI_estimator_name='smile',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.17420943012696222

# %% [markdown]
# ### 2. PS

# %%
ps_obs=np.load('dataset/data_for_paper/signal_with_fg_ns/PS.npy')
param=np.load('dataset/data_for_paper/signal_with_fg_ns/params.npy')

# %%
ps_obs=(ps_obs-np.mean(ps_obs,axis=0))/np.std(ps_obs,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    ps_obs,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 0.4414170346313957

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    ps_obs,
    param,
    MI_estimator_name='nwj',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.08368199203678509

# %% [markdown]
# ### 3. BS

# %%
bs_obs=np.load('dataset/data_for_paper/signal_with_fg_ns/BS.npy')
param=np.load('dataset/data_for_paper/signal_with_fg_ns/params.npy')

# %%
bs_obs=(bs_obs-np.mean(bs_obs,axis=0))/np.std(bs_obs,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
mask=feature_selection(bs_obs,param)
bs_obs=bs_obs[:,mask]

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    bs_obs,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# -0.04968965434489214

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    bs_obs,
    param,
    MI_estimator_name='smile',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.14857661246297837

# %% [markdown]
# ### 4. BS&PS

# %%
bs_obs=np.load('dataset/data_for_paper/signal_with_fg_ns/BS.npy')
ps_obs=np.load('dataset/data_for_paper/signal_with_fg_ns/PS.npy')

pb_obs=np.hstack([ps_obs,bs_obs])
param=np.load('dataset/data_for_paper/signal_with_fg_ns/params.npy')

# %%
pb_obs=(pb_obs-np.mean(pb_obs,axis=0))/np.std(pb_obs,axis=0)

param=(param-np.array([5,1.7]))/np.array([1,0.7])

# %%
mask=feature_selection(pb_obs,param)
pb_obs=pb_obs[:,mask]

# %%
best_model,train_MIs,eval_MIs,total_MIs=train_ba(
    pb_obs,
    param,
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    verbose=True)

# %% [markdown]
# Final Results

# %%
total_MIs[-1]
# Out:
# 0.4388605318123344

# %%
best_model.eval();
train_MIs,eval_MIs,total_MIs=train_mine_with_r(
    pb_obs,
    param,
    MI_estimator_name='nwj',
    train_info={'epochs':2000,'batch_size':100,'learning_rate':1e-4,'weigth_decay':1e-4},
    r=best_model,
    verbose=True)

# %%
total_MIs[-1]
# Out:
# 0.12840833190925613

# %% [markdown]
# ## Plot All results

# %%
re_all=[{'ST_pure': 5.14+0.52,
  'BS&PS_pure': 4.68+0.06,
  'PS_pure': 4.03+0.29,
  'BS_pure': 3.75+0.24},
 {'ST_ns': 1.01+0.03,
  'BS&PS_ns': 1.04+0.13,
  'PS_ns': 0.68+0.14,
  'BS_ns': 0.33+0.04},
 {'ST_obs': 0.51+0.17,
  'BS&PS_obs': 0.43+0.13,
  'PS_obs': 0.44+0.08,
  'BS_obs': -0.05+0.15}]

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(21,7),facecolor=(1,1,1))

tick_names=[]
mi_total=[]
for i in range(len(re_all)):
    names, mis = zip(*re_all[i].items())
    
    plt.bar(np.arange(i*4,i*4+4),mis)
    
    mi_total=mi_total+list(mis)
    tick_names=tick_names+list(names)

plt.xticks(range(len(tick_names)), labels=tick_names,fontsize=15)
for i in range(len(tick_names)):
    plt.text(i-0.3, np.array(mi_total[i])+0.05, "{:.2f}".format(mi_total[i]), color='black', fontweight='bold',fontsize=15)

mi_total=np.array(mi_total)
plt.yticks(fontsize=15)
patches=[]
patches.append(mpatches.Patch(color='tab:blue',label='Pure Signal'))
patches.append(mpatches.Patch(color='tab:orange',label='with Thermal Noise'))
patches.append(mpatches.Patch(color='tab:green',label='with Thermal Noise and Residual Foreground'))
fig.legend(handles=patches,loc=(0.62,0.75),fontsize=15)
plt.ylabel(r"Estimated MI",fontsize=30)
plt.xlabel("Summary Statistics",fontsize=30)
# Out:
# Text(0.5, 0, 'Summary Statistics')
